# %% [markdown]
# # stretch (sepsis-pics)

# %% [markdown]
# ## common

# %%
import pandas as pd
from common_eicu import *

# %% [markdown]
# ## patient result

# %%
df_patient_result = pd.read_csv(
    eicu_path('apachePatientResult.csv.gz'),
)
df_patient_result.head()
# Out:
#    apachepatientresultsid  patientunitstayid           physicianspeciality  \
# 0                   26570             141168  critical care medicine (CCM)
# 1                   26571             141168  critical care medicine (CCM)
# 2                   53135             141194  critical care medicine (CCM)
# 3                   53136             141194  critical care medicine (CCM)
# 4                       8             141203                   hospitalist
#
#   physicianinterventioncategory  acutephysiologyscore  apachescore  \
# 0                       Unknown                    49           65
# 1                       Unknown                    49           65
# 2                       Unknown                    57           70
# 3                       Unknown                    57           70
# 4                             I                    73           90
#
#   apacheversion  predictedicumortality actualicumortality  predictediculos  \
# 0            IV               0.026988            EXPIRED         3.038388
# 1           IVa               0.028889            EXPIRED         3.091127
# 2            IV               0.037888              ALIVE         4.620982
# 3           IVa               0.046448              ALIVE         4.167129
# 4           IVa               0.291609              ALIVE         8.670299
#
#    ...  predictedhospitallos  actualhospitallos preopmi  preopcardiaccath  \
# 0  ...              7.546453             2.4972       0                 0
# 1  ...              6.628720             2.4972       0                 0
# 2  ...             13.338449             9.2167       0                 0
# 3  ...             12.978228             9.2167       0                 0
# 4  ...             16.319389             3.7493       0                 0
#
#    ptcawithin24h  unabridgedunitlos  unabridgedhosplos  actualventdays  \
# 0              0             2.4972             2.4972             NaN
# 1              0             2.4972             2.4972             NaN
# 2              0             3.3423             9.2167             NaN
# 3              0             3.3423             9.2167             NaN
# 4              0             1.2979             3.7493             2.0
#
#    predventdays  unabridgedactualventdays
# 0           NaN                       NaN
# 1           NaN                       NaN
# 2           NaN                       NaN
# 3           NaN                       NaN
# 4      5.738093                       2.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## treatment data

# %%
df_treatment = pd.read_csv(
    TREATMENT_PATH,
    nrows=5000,
)
df_treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   treatmentid          5000 non-null   int64
#  1   patientunitstayid    5000 non-null   int64
#  2   treatmentoffset      5000 non-null   int64
#  3   treatmentstring      5000 non-null   object
#  4   activeupondischarge  5000 non-null   bool
# dtypes: bool(1), int64(3), object(1)
# memory usage: 161.3+ KB

# %%
df_treatment[
    (df_treatment['patientunitstayid'] == 242290)
    & (
        df_treatment['treatmentstring'].map(
            lambda s: 'vasopressor' in s
        )
    )
]
# Out:
#      treatmentid  patientunitstayid  treatmentoffset  \
# 245      8645242             242290              162
# 253     10019133             242290              165
#
#                                        treatmentstring  activeupondischarge
# 245  cardiovascular|shock|vasopressors|norepinephri...                False
# 253  cardiovascular|shock|vasopressors|norepinephri...                 True

# %% [markdown]
# ## exam data

# %%
df_exam = pd.read_csv(
    EXAM_PATH,
    nrows=5000,
)
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   physicalexamid      5000 non-null   int64
#  1   patientunitstayid   5000 non-null   int64
#  2   physicalexamoffset  5000 non-null   int64
#  3   physicalexampath    5000 non-null   object
#  4   physicalexamvalue   5000 non-null   object
#  5   physicalexamtext    5000 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 234.5+ KB

# %%
df = df_exam[df_exam['physicalexamvalue'] == 'HR Current']
df = df[['patientunitstayid', 'physicalexamoffset']]
df.groupby('patientunitstayid').count()['physicalexamoffset'].unique()
# df_exam[
#     (
#         df_exam['physicalexamvalue'].map(
#             lambda s: 'hr' in s.lower()
#         )
#     )
#     & (df_exam['patientunitstayid'] == 208303)
# ]
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ## lab data

# %%
df_lab = pd.read_csv(
    LAB_PATH,
    # nrows=5000,
)

# %%
# df_lab[df_lab['patientunitstayid'] == 242505][['patientunitstayid','labname']] \
#     .groupby('labname').count()
df_lab[
    (df_lab['patientunitstayid'] == 242505)
    & (df_lab['labname'].isin(['albumin', '-lymphs']))
].sort_values(by='labresultoffset')
# Out:
#             labid  patientunitstayid  labresultoffset  labtypeid  labname  \
# 2550944  77669285             242505             -183          3  -lymphs
# 2550971  72844772             242505             -183          1  albumin
# 2550865  77712847             242505              495          3  -lymphs
# 2550997  72890845             242505              495          1  albumin
# 2550906  72884088             242505             1995          1  albumin
# 2550909  77706505             242505             1995          3  -lymphs
# 2550837  77705296             242505             3401          3  -lymphs
# 2550950  72882635             242505             3401          1  albumin
# 2550859  77704913             242505             4907          3  -lymphs
# 2550991  72882111             242505             4907          1  albumin
#
#          labresult labresulttext labmeasurenamesystem labmeasurenameinterface  \
# 2550944       11.7          11.7                    %                       %
# 2550971        3.1           3.1                 g/dL                    g/dL
# 2550865        9.0           9.0                    %                       %
# 2550997        2.2           2.2                 g/dL                    g/dL
# 2550906        2.1           2.1                 g/dL                    g/dL
# 2550909        9.9           9.9                    %                       %
# 2550837       11.1          11.1                    %                       %
# 2550950        2.4           2.4                 g/dL                    g/dL
# 2550859       11.2          11.2                    %                       %
# 2550991        3.4           3.4                 g/dL                    g/dL
#
#          labresultrevisedoffset
# 2550944                    -166
# 2550971                    -129
# 2550865                     507
# 2550997                     525
# 2550906                    2024
# 2550909                    2010
# 2550837                    3415
# 2550950                    3432
# 2550859                    4919
# 2550991                    4939

# %% [markdown]
# ## data output (raw)

# %%
df_raw_na = pd.read_csv(
    './data_eicu_compact_raw_na.csv.gz',
    index_col='patientunitstayid',
)
df_raw_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167643 entries, 141168 to 3353263
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   age                167609 non-null  float64
#  1   urine              167556 non-null  float64
#  2   wbc                167556 non-null  float64
#  3   meanbp             167556 non-null  float64
#  4   actualhospitallos  148519 non-null  float64
#  5   vasopressor        167643 non-null  int64
#  6   hr                 126207 non-null  float64
#  7   creatinine         162908 non-null  float64
#  8   platelet           160718 non-null  float64
#  9   inr                111483 non-null  float64
#  10  pt                 108660 non-null  float64
#  11  ptt                82703 non-null   float64
#  12  lactate            66618 non-null   float64
#  13  rdw                152070 non-null  float64
#  14  bilirubin          119313 non-null  float64
#  15  bicarbonate        153378 non-null  float64
#  16  crp                6735 non-null    float64
#  17  lymph              128882 non-null  float64
#  18  albumin            126918 non-null  float64
#  19  prealbumin         9799 non-null    float64
# dtypes: float64(19), int64(1)
# memory usage: 26.9 MB

# %%
df_raw_na.head()
# Out:
#                     age  urine   wbc  meanbp  actualhospitallos  vasopressor  \
# patientunitstayid
# 141168             70.0   -1.0  14.7    62.0             2.4972            0
# 141178             52.0   -1.0  -1.0    -1.0                NaN            0
# 141179             52.0    NaN   NaN     NaN                NaN            0
# 141194             68.0   -1.0  14.1    40.0             9.2167            0
# 141196             71.0    NaN   NaN     NaN                NaN            0
#
#                       hr  creatinine  platelet   inr     pt    ptt  lactate  \
# patientunitstayid
# 141168               NaN    2.400000     203.0  2.86  30.62  32.50     12.2
# 141178               NaN    0.700000     273.0   NaN    NaN    NaN      NaN
# 141179               NaN    0.700000     219.0   NaN    NaN    NaN      NaN
# 141194             112.0    2.108571     190.5  1.10  12.10  32.25      1.5
# 141196               NaN    0.840000     497.0   NaN    NaN    NaN      0.8
#
#                          rdw  bilirubin  bicarbonate  crp      lymph  \
# patientunitstayid
# 141168             18.066667   3.966667    22.000000  NaN  11.666667
# 141178             11.900000   0.400000    25.000000  NaN  45.000000
# 141179             11.900000        NaN    24.000000  NaN        NaN
# 141194             16.240000   0.400000    21.071429  NaN  17.000000
# 141196             13.633333   0.300000    31.000000  NaN   5.666667
#
#                     albumin  prealbumin
# patientunitstayid
# 141168             3.133333         NaN
# 141178             4.000000         NaN
# 141179                  NaN         NaN
# 141194             2.650000         NaN
# 141196             2.500000         NaN

# %%
df_raw_na[df_raw_na['actualhospitallos'] <= 1]
# Out:
#                     age      urine  wbc  meanbp  actualhospitallos  \
# patientunitstayid
# 141208             25.0    -1.0000 -1.0    68.0             0.4215
# 141314             45.0    -1.0000  1.9    40.0             0.7535
# 141786             75.0    -1.0000  7.0   136.0             0.8063
# 141939             56.0    -1.0000 -1.0   124.0             0.4410
# 141970             18.0    -1.0000  4.6    51.0             0.6375
# ...                 ...        ...  ...     ...                ...
# 3352747            30.0  4365.1872 -1.0    67.0             0.9278
# 3352800            41.0  4266.6048  6.5   139.0             0.5813
# 3353038            27.0    -1.0000  7.5   115.0             0.9069
# 3353067            63.0  2952.8928  7.7   109.0             0.6132
# 3353070            66.0    -1.0000 -1.0    55.0             0.2514
#
#                    vasopressor     hr  creatinine  platelet  inr    pt   ptt  \
# patientunitstayid
# 141208                       0    NaN    0.800000     440.0  NaN   NaN   NaN
# 141314                       0    NaN    1.806667     172.5  1.5  15.7  51.0
# 141786                       0    NaN    1.810000     225.0  1.1  10.6  28.0
# 141939                       0   68.0         NaN       NaN  NaN   NaN   NaN
# 141970                       0   58.0    1.050000     341.5  NaN   NaN   NaN
# ...                        ...    ...         ...       ...  ...   ...   ...
# 3352747                      0   62.0         NaN       NaN  NaN   NaN   NaN
# 3352800                      0  106.0    1.950000     210.0  NaN   NaN   NaN
# 3353038                      0    NaN    0.660000     320.5  1.1  11.6  32.0
# 3353067                      0   93.0    0.740000     203.0  NaN   NaN   NaN
# 3353070                      0   63.0         NaN       NaN  NaN   NaN   NaN
#
#                      lactate     rdw  bilirubin  bicarbonate  crp      lymph  \
# patientunitstayid
# 141208                   NaN  12.900   0.700000         27.0  NaN  24.000000
# 141314             21.566667  16.075   0.733333         22.0  NaN  29.666667
# 141786                   NaN  14.050   0.300000         30.0  NaN  27.000000
# 141939                   NaN     NaN        NaN          NaN  NaN        NaN
# 141970                   NaN  13.150   0.450000         25.5  NaN  42.000000
# ...                      ...     ...        ...          ...  ...        ...
# 3352747                  NaN     NaN        NaN          NaN  NaN        NaN
# 3352800                  NaN  16.200        NaN         23.0  NaN        NaN
# 3353038             0.800000  14.450   0.450000         22.0  NaN  28.500000
# 3353067             1.000000  13.400   1.600000         27.0  NaN        NaN
# 3353070                  NaN     NaN        NaN          NaN  NaN        NaN
#
#                    albumin  prealbumin
# patientunitstayid
# 141208                 4.7         NaN
# 141314                 2.5         NaN
# 141786                 3.1         NaN
# 141939                 NaN         NaN
# 141970                 3.7         NaN
# ...                    ...         ...
# 3352747                NaN         NaN
# 3352800                NaN         NaN
# 3353038                4.3         NaN
# 3353067                3.9         NaN
# 3353070                NaN         NaN
#
# [6775 rows x 20 columns]

# %% [markdown]
# ## data output (sepsis)

# %%
df_sepsis_na = pd.read_csv(
    './data_eicu_compact_sepsis_na.csv',
    index_col='patientunitstayid',
)
df_sepsis_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22009 entries, 141227 to 3353251
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                22009 non-null  float64
#  1   urine              22008 non-null  float64
#  2   wbc                22008 non-null  float64
#  3   meanbp             22008 non-null  float64
#  4   actualhospitallos  19470 non-null  float64
#  5   vasopressor        22009 non-null  int64
#  6   hr                 18499 non-null  float64
#  7   creatinine         21753 non-null  float64
#  8   platelet           21657 non-null  float64
#  9   inr                16182 non-null  float64
#  10  pt                 15821 non-null  float64
#  11  ptt                11861 non-null  float64
#  12  lactate            17464 non-null  float64
#  13  rdw                20286 non-null  float64
#  14  bilirubin          19252 non-null  float64
#  15  bicarbonate        20339 non-null  float64
#  16  crp                1577 non-null   float64
#  17  lymph              18384 non-null  float64
#  18  albumin            20090 non-null  float64
#  19  prealbumin         2290 non-null   float64
# dtypes: float64(19), int64(1)
# memory usage: 3.5 MB

# %%
len(
    df_sepsis_na.dropna(
        subset=list(
            set(df_sepsis_na.columns) - set(['crp', 'prealbumin'])  # 5151
            # set(df_sepsis_na.columns) - set(['crp'])  # 817
            # set(df_sepsis_na.columns) - set(['prealbumin'])  # 403
        )
    )
)
# Out:
# 5151

# %% [markdown]
# ## output data (pics checked)

# %%
df_pics = pd.read_csv('./data_eicu_compact_pics.csv')
df_pics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientunitstayid  2193 non-null   int64
#  1   age                2193 non-null   float64
#  2   urine              2193 non-null   float64
#  3   wbc                2193 non-null   float64
#  4   meanbp             2193 non-null   float64
#  5   vasopressor        2193 non-null   int64
#  6   hr                 2193 non-null   float64
#  7   creatinine         2193 non-null   float64
#  8   platelet           2193 non-null   float64
#  9   inr                2193 non-null   float64
#  10  pt                 2193 non-null   float64
#  11  ptt                2193 non-null   float64
#  12  lactate            2193 non-null   float64
#  13  rdw                2193 non-null   float64
#  14  bilirubin          2193 non-null   float64
#  15  bicarbonate        2193 non-null   float64
#  16  pics               2193 non-null   bool
# dtypes: bool(1), float64(14), int64(2)
# memory usage: 276.4 KB

# %%
n_sepsis = len(df_pics)
pics_mask = df_pics['pics'].map(bool)
n_pics = len(df_pics[pics_mask])
pct = n_pics / n_sepsis
print(f'PICS: {pct:.2%}')
# Out:
# PICS: 0.68%
